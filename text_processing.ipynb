# %% [markdown]
# # Text Processing
#
# ## Capturing Text Data
#
# ### Plain Text

# %%
import os

# Read in a plain text file
with open(os.path.join("data", "hieroglyph.txt"), "r") as f:
    text = f.read()
    print(text)
# Out:
# Hieroglyphic writing dates from c. 3000 BC, and is composed of hundreds of symbols. A hieroglyph can represent a word, a sound, or a silent determinative; and the same symbol can serve different purposes in different contexts. Hieroglyphs were a formal script, used on stone monuments and in tombs, that could be as detailed as individual works of art.

# %% [markdown]
# ### Tabular Data

# %%
import pandas as pd

# Extract text column from a dataframe
df = pd.read_csv(os.path.join("data", "news.csv"))
df.head()[['publisher', 'title']]

# Convert text column to lowercase
df['title'] = df['title'].str.lower()
df.head()[['publisher', 'title']]
# Out:
#       publisher                                              title
# 0      Livemint  fed's charles plosser sees high bar for change...
# 1  IFA Magazine  us open: stocks fall after fed official hints ...
# 2  IFA Magazine  fed risks falling 'behind the curve', charles ...
# 3     Moneynews  fed's plosser: nasty weather has curbed job gr...
# 4        NASDAQ  plosser: fed may have to accelerate tapering pace

# %% [markdown]
# ### Online Resource

# %%
import requests
import json

# Fetch data from a REST API
r = requests.get(
    "https://quotes.rest/qod.json")
res = r.json()
print(json.dumps(res, indent=4))

# Extract relevant object and field
q = res["contents"]["quotes"][0]
print(q["quote"], "\n--", q["author"])
# Out:
# {
#     "success": {
#         "total": 1
#     },
#     "contents": {
#         "quotes": [
#             {
#                 "quote": "If you respect yourself in stressful situations, it will help you see the positive\u2026 It will help you see the message in the mess.",
#                 "author": "Steve Maraboli",
#                 "length": "135",
#                 "tags": [
#                     "inspire",
#                     "self-respect",
#                     "stress"
#                 ],
#                 "category": "inspire",
#                 "title": "Inspiring Quote of the day",
#                 "date": "2019-01-17",
#                 "id": null
#             }
#         ],
#         "copyright": "2017-19 theysaidso.com"
#     }
# }
# If you respect yourself in stressful situations, it will help you see the positive… It will help you see the message in the mess.
# -- Steve Maraboli

# %% [markdown]
# ## Cleaning

# %%
import requests

# Fetch a web page
r = requests.get("https://news.ycombinator.com")
print(r.text)
# Out:
# <html op="news"><head><meta name="referrer" content="origin"><meta name="viewport" content="width=device-width, initial-scale=1.0"><link rel="stylesheet" type="text/css" href="news.css?qZmEZPl98MeFlXRlm5qn">
#             <link rel="shortcut icon" href="favicon.ico">
#           <link rel="alternate" type="application/rss+xml" title="RSS" href="rss">
#         <title>Hacker News</title></head><body><center><table id="hnmain" border="0" cellpadding="0" cellspacing="0" width="85%" bgcolor="#f6f6ef">
#         <tr><td bgcolor="#ff6600"><table border="0" cellpadding="0" cellspacing="0" width="100%" style="padding:2px"><tr><td style="width:18px;padding-right:4px"><a href="https://news.ycombinator.com"><img src="y18.gif" width="18" height="18" style="border:1px white solid;"></a></td>
#                   <td style="line-height:12pt; height:10px;"><span class="pagetop"><b class="hnname"><a href="news">Hacker News</a></b>
#               <a href="newest">new</a> | <a href="newcomments">comments</a> | <a href="ask">ask</a> | <a href="show">show</a> | <a href="jobs">jobs</a> | <a href="submit">submit</a>            </span></td><td style="text-align:right;padding-right:4px;"><span class="pagetop">
#                               <a href="login?goto=news">login</a>
#                           </span></td>
#               </tr></table></td></tr>
# <tr id="pagespace" title="" style="height:10px"></tr><tr><td><table border="0" cellpadding="0" cellspacing="0" class="itemlist">
#               <tr class='athing' id='18926225'>
#       <td align="right" valign="top" class="title"><span class="rank">1.</span></td>      <td valign="top" class="votelinks"><center><a id='up_
#           <input type="text" name="q" value="" size="17" autocorrect="off" spellcheck="false" autocapitalize="off" autocomplete="false"></form>
#             </center></td></tr>
#       </table></center></body><script type='text/javascript' src='hn.js?qZmEZPl98MeFlXRlm5qn'></script>
#   </html>

# %%
import re

# Remove HTML tags using RegEx
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('', r.text))  # replace them with blank
# Out:
#
#
#         Hacker News
#
#                   Hacker News
#               new | comments | ask | show | jobs | submit
#                               login
#
#
#
#
#       1.      John C. Bogle, Founder of Vanguard Group, Has Died (wsj.com)
#         797 points by gdubs 7 hours ago  | hide | 141&nbsp;comments
#
#
#       2.      Networking on AWS (grahamlyons.com)
#         328 points by petercooper 8 hours ago  | hide | 67&nbsp;comments
#
#
#       3.      How to Find Hidden Cameras and Spy Gear Like a Professional (senteltechsecurity.com)
#         228 points by loteck 7 hours ago  | hide | 67&nbsp;comments
#
#
#       4.      600 days of postmarketOS (postmarketos.org)
#         54 points by ollieparanoid 3 hours ago  | hide | 5&nbsp;comments
#
#
#       5.      Microsoft pledges $500M for affordable housing in Seattle area (nytimes.com)
#         188 points by pgodzin 3 hours ago  | hide | 99&nbsp;comments
#
#
#       6.      What’s Causing the Rise of Hoarding Disorder? (jstor.org)
#         24 points by toufiqbarhamov 2 hours ago  | hide | 19&nbsp;comments
#
#
#       7.      Tech Choices I Regret at Spectrum (mxstbr.com)
#         190 points by theBashShell 9 hours ago  | hide | 77&nbsp;comments
#
#
#       8.      The Route of a Text Message (scottbot.net)
#         437 points by ericlott 14 hours ago  | hide | 53&nbsp;comments
#
#
#       9.      Mastercard will stop free trials from automatically billing you once it's over (theverge.com)
#         192 points by hbcondo714 4 hours ago  | hide | 82&nbsp;comments
#
#
#       10.      Zillow CEO: startups trying to disrupt real estate commissions will fail (2012) (geekwire.com)
#         141 points by gamechangr 9 hours ago  | hide | 246&nbsp;comments
#
#
#       11.      The 773M Record “Collection #1” Data Breach (troyhunt.com)
#         123 points by shritesh 8 hours ago  | hide | 34&nbsp;comments
#
#
#       12.      Cloud Functions: Go 1.11 is now a supported language (cloud.google.com)
#         211 points by yannikyeo 12 hours ago  | hide | 83&nbsp;comments
#
#
#       13.      More than you really wanted to know about patch (landley.net)
#         73 points by signa11 7 hours ago  | hide | 5&nbsp;comments
#
#
#       14.      Automating Datacenter Operations at Dropbox (dropbox.com)
#         39 points by dmicher 6 hours ago  | hide | 4&nbsp;comments
#
#
#       15.      ArangoDB: Multi-model highly available NoSQL database (arangodb.com)
#         65 points by giancarlostoro 7 hours ago  | hide | 25&nbsp;comments
#
#
#       16.      Reading Proust in the Gulag (nytimes.com)
#         4 points by pseudolus 2 hours ago  | hide | 1&nbsp;comment
#
#
#       17.      Measuring Traffic Manipulation on Twitter (ox.ac.uk)
#         16 points by DyslexicAtheist 4 hours ago  | hide | 3&nbsp;comments
#
#
#       18.      Machine Learning Music Composed by Fragments of 100s of Terabytes of Recordings (nwn.blogs.com)
#         45 points by Kroeler 8 hours ago  | hide | 11&nbsp;comments
#
#
#       19.      YC Series A Program Investor Access (ycombinator.com)
#         72 points by katm 10 hours ago  | hide | 7&nbsp;comments
#
#
#       20.      Blockstream Satellite API: Pay with BTC via Lightning to Broadcast Data Globally (blockstream.com)
#         77 points by grubles 9 hours ago  | hide | 28&nbsp;comments
#
#
#       21.      Illinois Bet on Video Gambling and Lost (propublica.org)
#         129 points by danso 14 hours ago  | hide | 169&nbsp;comments
#
#
#       22.      AI Is About To Take The Ship's Helm Away From Humans (forbes.com)
#         26 points by howrude 6 hours ago  | hide | 25&nbsp;comments
#
#
#       23.      DOJ: Hackers broke into an SEC database and made millions from inside info (cnbc.com)
#         393 points by djoldman 16 hours ago  | hide | 147&nbsp;comments
#
#
#       24.      Elsevier journal editors resign, start rival open-access journal (insidehighered.com)
#         802 points by dankohn1 21 hours ago  | hide | 106&nbsp;comments
#
#
#       25.      Crisis on the High Plains:The Loss of America’s Largest Aquifer – Ogallala(2018) (duwaterlawreview.com)
#         32 points by jelliclesfarm 6 hours ago  | hide | 17&nbsp;comments
#
#
#       26.       Byju’s buys Osmo for $120M to add blended learning to its education business (techcrunch.com)
#         47 points by erohead 8 hours ago  | hide | 9&nbsp;comments
#
#
#       27.      After GDPR, The New York Times cut off ad exchanges and kept growing ad revenue (digiday.com)
#         523 points by chrisxcross 18 hours ago  | hide | 404&nbsp;comments
#
#
#       28.      Ford: We're going to make F-Series all-electric (freep.com)
#         149 points by prostoalex 7 hours ago  | hide | 197&nbsp;comments
#
#
#       29.      Concept design for a post-LHC future circular collider at CERN (home.cern)
#         87 points by est31 13 hours ago  | hide | 65&nbsp;comments
#
#
#       30.      VPS VPN – GhostiFi (ghostifi.net)
#         37 points by GordonS 7 hours ago  | hide | 21&nbsp;comments
#
#             More
#
#
# Guidelines
#         | FAQ
#         | Support
#         | API
#         | Security
#         | Lists
#         | Bookmarklet
#         | Legal
#         | Apply to YC
#         | ContactSearch:

# %%
from bs4 import BeautifulSoup

# Remove HTML tags using Beautiful Soup library
soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
#
#
#         Hacker News
#
#                   Hacker News
#               new | comments | ask | show | jobs | submit
#                               login
#
#
#
#
#       1.      John C. Bogle, Founder of Vanguard Group, Has Died (wsj.com)
#         797 points by gdubs 7 hours ago  | hide | 141 comments
#
#
#       2.      Networking on AWS (grahamlyons.com)
#         328 points by petercooper 8 hours ago  | hide | 67 comments
#
#
#       3.      How to Find Hidden Cameras and Spy Gear Like a Professional (senteltechsecurity.com)
#         228 points by loteck 7 hours ago  | hide | 67 comments
#
#
#       4.      600 days of postmarketOS (postmarketos.org)
#         54 points by ollieparanoid 3 hours ago  | hide | 5 comments
#
#
#       5.      Microsoft pledges $500M for affordable housing in Seattle area (nytimes.com)
#         188 points by pgodzin 3 hours ago  | hide | 99 comments
#
#
#       6.      What’s Causing the Rise of Hoarding Disorder? (jstor.org)
#         24 points by toufiqbarhamov 2 hours ago  | hide | 19 comments
#
#
#       7.      Tech Choices I Regret at Spectrum (mxstbr.com)
#         190 points by theBashShell 9 hours ago  | hide | 77 comments
#
#
#       8.      The Route of a Text Message (scottbot.net)
#         437 points by ericlott 14 hours ago  | hide | 53 comments
#
#
#       9.      Mastercard will stop free trials from automatically billing you once it's over (theverge.com)
#         192 points by hbcondo714 4 hours ago  | hide | 82 comments
#
#
#       10.      Zillow CEO: startups trying to disrupt real estate commissions will fail (2012) (geekwire.com)
#         141 points by gamechangr 9 hours ago  | hide | 246 comments
#
#
#       11.      The 773M Record “Collection #1” Data Breach (troyhunt.com)
#         123 points by shritesh 8 hours ago  | hide | 34 comments
#
#
#       12.      Cloud Functions: Go 1.11 is now a supported language (cloud.google.com)
#         211 points by yannikyeo 12 hours ago  | hide | 83 comments
#
#
#       13.      More than you really wanted to know about patch (landley.net)
#         73 points by signa11 7 hours ago  | hide | 5 comments
#
#
#       14.      Automating Datacenter Operations at Dropbox (dropbox.com)
#         39 points by dmicher 6 hours ago  | hide | 4 comments
#
#
#       15.      ArangoDB: Multi-model highly available NoSQL database (arangodb.com)
#         65 points by giancarlostoro 7 hours ago  | hide | 25 comments
#
#
#       16.      Reading Proust in the Gulag (nytimes.com)
#         4 points by pseudolus 2 hours ago  | hide | 1 comment
#
#
#       17.      Measuring Traffic Manipulation on Twitter (ox.ac.uk)
#         16 points by DyslexicAtheist 4 hours ago  | hide | 3 comments
#
#
#       18.      Machine Learning Music Composed by Fragments of 100s of Terabytes of Recordings (nwn.blogs.com)
#         45 points by Kroeler 8 hours ago  | hide | 11 comments
#
#
#       19.      YC Series A Program Investor Access (ycombinator.com)
#         72 points by katm 10 hours ago  | hide | 7 comments
#
#
#       20.      Blockstream Satellite API: Pay with BTC via Lightning to Broadcast Data Globally (blockstream.com)
#         77 points by grubles 9 hours ago  | hide | 28 comments
#
#
#       21.      Illinois Bet on Video Gambling and Lost (propublica.org)
#         129 points by danso 14 hours ago  | hide | 169 comments
#
#
#       22.      AI Is About To Take The Ship's Helm Away From Humans (forbes.com)
#         26 points by howrude 6 hours ago  | hide | 25 comments
#
#
#       23.      DOJ: Hackers broke into an SEC database and made millions from inside info (cnbc.com)
#         393 points by djoldman 16 hours ago  | hide | 147 comments
#
#
#       24.      Elsevier journal editors resign, start rival open-access journal (insidehighered.com)
#         802 points by dankohn1 21 hours ago  | hide | 106 comments
#
#
#       25.      Crisis on the High Plains:The Loss of America’s Largest Aquifer – Ogallala(2018) (duwaterlawreview.com)
#         32 points by jelliclesfarm 6 hours ago  | hide | 17 comments
#
#
#       26.       Byju’s buys Osmo for $120M to add blended learning to its education business (techcrunch.com)
#         47 points by erohead 8 hours ago  | hide | 9 comments
#
#
#       27.      After GDPR, The New York Times cut off ad exchanges and kept growing ad revenue (digiday.com)
#         523 points by chrisxcross 18 hours ago  | hide | 404 comments
#
#
#       28.      Ford: We're going to make F-Series all-electric (freep.com)
#         149 points by prostoalex 7 hours ago  | hide | 197 comments
#
#
#       29.      Concept design for a post-LHC future circular collider at CERN (home.cern)
#         87 points by est31 13 hours ago  | hide | 65 comments
#
#
#       30.      VPS VPN – GhostiFi (ghostifi.net)
#         37 points by GordonS 7 hours ago  | hide | 21 comments
#
#             More
#
#
# Guidelines
#         | FAQ
#         | Support
#         | API
#         | Security
#         | Lists
#         | Bookmarklet
#         | Legal
#         | Apply to YC
#         | ContactSearch:

# %%
# Find all articles
summaries = soup.find_all("tr", class_="athing")
summaries[0]
# Out:
# <tr class="athing" id="18926225">
#       <td align="right" class="title" valign="top"><span class="rank">1.</span></td>      <td class="votelinks" valign="top"><center><a href="vote?id=18926225&amp;how=up&amp;goto=news" id="up_18926225"><div class="votearrow" title="upvote"></div></a></center></td><td class="title"><a class="storylink" href="https://www.wsj.com/articles/john-c-bogle-founder-of-vanguard-group-dies-11547677745">John C. Bogle, Founder of Vanguard Group, Has Died</a><span class="sitebit comhead"> (<a href="from?site=wsj.com"><span class="sitestr">wsj.com</span></a>)</span></td></tr>

# %%
# Extract title
summaries[0].find("a", class_="storylink").get_text().strip()
# Out:
# 'John C. Bogle, Founder of Vanguard Group, Has Died'

# %%
# Find all articles, extract titles
articles = []
summaries = soup.find_all("tr", class_="athing")
for summary in summaries:
    title = summary.find("a", class_="storylink").get_text().strip()
    articles.append((title))

print(len(articles), "Article summaries found. Sample:")
print(articles[0])
# Out:
# 30 Article summaries found. Sample:
# John C. Bogle, Founder of Vanguard Group, Has Died

# %% [markdown]
# ## Normalization

# %% [markdown]
# ### Case Normalization

# %%
# Sample text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"
print(text)
# Out:
# The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?

# %%
# Convert to lowercase
text = text.lower() 
print(text)
# Out:
# the first time you see the second renaissance it may look boring. look at it at least twice and definitely watch part 2. it will change your view of the matrix. are the human people the ones who started the war ? is ai a bad thing ?

# %% [markdown]
# ### Punctuation Removal

# %%
import re

# Remove punctuation characters
text = re.sub(r"[^a-zA-Z0-9]", " ", text) 
print(text)
# Out:
# Dr  Smith graduated from the University of Washington  He later started an analytics firm called Lux  which catered to enterprise customers

# %% [markdown]
# ## Tokenization

# %%
# Split text into tokens (words)
words = text.split()
print(words)
# Out:
# ['Dr', 'Smith', 'graduated', 'from', 'the', 'University', 'of', 'Washington', 'He', 'later', 'started', 'an', 'analytics', 'firm', 'called', 'Lux', 'which', 'catered', 'to', 'enterprise', 'customers']

# %% [markdown]
# ### NLTK: Natural Language ToolKit

# %%
import os
import nltk
nltk.data.path.append(os.path.join(os.getcwd(), "nltk_data"))

# %%
# Another sample text
text = "Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers."
print(text)
# Out:
# Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers.

# %%
from nltk.tokenize import word_tokenize

# Split text into words using NLTK
words = word_tokenize(text)
print(words)
# Out:
# ['Dr.', 'Smith', 'graduated', 'from', 'the', 'University', 'of', 'Washington', '.', 'He', 'later', 'started', 'an', 'analytics', 'firm', 'called', 'Lux', ',', 'which', 'catered', 'to', 'enterprise', 'customers', '.']

# %%
from nltk.tokenize import sent_tokenize

# Split text into sentences
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Dr. Smith graduated from the University of Washington.', 'He later started an analytics firm called Lux, which catered to enterprise customers.']

# %%
# List stop words
from nltk.corpus import stopwords
print(stopwords.words("english"))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# Reset text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"

# Normalize it
text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())

# Tokenize it
words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %%
# Remove stop words
words = [w for w in words if w not in stopwords.words("english")]
print(words)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'boring', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'ones', 'started', 'war', 'ai', 'bad', 'thing']

# %% [markdown]
# ### Sentence Parsing

# %%
import nltk

# Define a custom grammar
my_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
""")
parser = nltk.ChartParser(my_grammar)

# Parse a sentence
sentence = word_tokenize("I shot an elephant in my pajamas")
for tree in parser.parse(sentence):
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %% [markdown]
# ## Stemming & Lemmatization
#
# ### Stemming

# %%
from nltk.stem.porter import PorterStemmer

# Reduce words to their stems
stemmed = [PorterStemmer().stem(w) for w in words]
print(stemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaiss', 'may', 'look', 'bore', 'look', 'least', 'twice', 'definit', 'watch', 'part', '2', 'chang', 'view', 'matrix', 'human', 'peopl', 'one', 'start', 'war', 'ai', 'bad', 'thing']

# %% [markdown]
# ### Lemmatization

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# Reduce words to their root form
lemmed = [WordNetLemmatizer().lemmatize(w) for w in words]
print(lemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'boring', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'one', 'started', 'war', 'ai', 'bad', 'thing']

# %%
# Lemmatize verbs by specifying pos
lemmed = [WordNetLemmatizer().lemmatize(w, pos='v') for w in lemmed]
print(lemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'bore', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'one', 'start', 'war', 'ai', 'bad', 'thing']
